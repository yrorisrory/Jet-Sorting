# %%
import uproot
import numpy as np

# Open your processed ROOT file
file = uproot.open("/uscms/home/rconnor/nobackup/CMSSW_13_3_1/src/jet_sorting/final/outputs/WbWb/7-3.root")
tree = file["tree"]  # adjust if your TTree has a different name

# Load branches as numpy arrays
lab_nAK4   = tree["lab_nAK4"].array(library="np")        # number of AK4 jets per event
lab_AK4_pt = tree["lab_AK4_pt"].array(library="np")      # AK4 pT
AK4_eta    = tree["AK4_eta"].array(library="np")         # AK4 eta
AK4_phi    = tree["AK4_phi"].array(library="np")         # AK4 phi
AK4_mass   = tree["AK4_mass"].array(library="np")        # AK4 mass
jet_mass   = tree["jet_mass"].array(library="np")        # fat jet masses
fails_veto = tree["AK4_fails_veto_map"].array(library="np")  # boolean veto map
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /cvmfs/cms.cern.ch/el9_amd64_gcc12/external/py3-uproot/5.0.7-ab9ea3fd9bd57d186662b2d52387e89a/lib/python3.9/site-packages/uproot/source/file.py:112, in MemmapSource._open(self)
#     111 try:
# --> 112     self._file = numpy.memmap(self._file_path, dtype=self._dtype, mode="r")
#     113     self._fallback = None
#
# File /cvmfs/cms.cern.ch/el9_amd64_gcc12/external/py3-numpy/1.24.3-a3a65cbc18c6a98e06451d4329e3ea47/lib/python3.9/site-packages/numpy/core/memmap.py:228, in memmap.__new__(subtype, filename, dtype, mode, offset, shape, order)
#     227 else:
# --> 228     f_ctx = open(os_fspath(filename), ('r' if mode == 'c' else mode)+'b')
#     230 with f_ctx as fid:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'jet_sorting/final/outputs/WbWb/7-3.root'
#
# ...
